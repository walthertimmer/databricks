# %% [markdown]
# ## Local Python Portfolio analysis

# %%
pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: C:\Users\timmer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import yfinance as yf


def get_quote_info(ticker):
    print(f"collecting data for: {ticker}")
    ticker_info = yf.Ticker(f"{ticker}")
    if debug:
        print(ticker_info.info)

    

    #ask_price = ticker_info.info['ask']
    # dividend_rate = ticker_info.info['dividendRate']
    # dividend_yield = ticker_info.info['dividendYield']
    # payout_ratio = ticker_info.info['payoutRatio']
    # pe_rate = ticker_info.info['forwardPE'] # price / earnings rate
    # fiveYearAvgDividendYield
    # beta
    # trailingPE
    # marketCap
    # currency
    # profitMargins
    # bookValue
    # priceToBook
    # earningsQuarterlyGrowth
    # trailingEps
    # forwardEps
    # pegRatio
    # enterpriseToRevenue
    # enterpriseToEbitda
    # shortName
    # currentPrice
    # recommendationMean
    # recommendationKey
    # quickRatio
    # currentRatio
    # debutToEquity
    # revenuePerShare
    # returnOnAssets
    # returnOnEquity
    # earningsGrowth
    # revenueGrowth
    # grossMargins
    # ebitdaMargings
    # operatingMargings
    # trailingPegRatio
    return ticker_info.info

# %%
# single testcase
debug = True
get_quote_info("MSFT")
debug = False
# Out:
# collecting data for: MSFT
# ...

# %%
# stocks to analyze
stocks = [
    ('AAPL') #Apple
    ,('MSFT') # Microsoft
    ,('NVDA') # Nvidia
    ,('AMD') # Advanced Micro Devices Inc.
    ,('BUD') # Anheuser-Busch InBev
    ,('V') # VISA
    ,('AMZN') # Amazon
    ,('META') # Facebook
    ,('WMT') # Walmart
    ,('NSRGY') # Nestle
    ,('UNA.AS') # Unilever
    ,('DANOY') # Danone
    ,('OR.PA') # L'oreal
    ,
]

# %%
# maybe build in a wait to not irritate yahoo?
import pandas as pd

debug = False
results = []

for ticker in stocks:
    result = get_quote_info(ticker)
    results.append(result)

# only create dataframe at the end to speedup process
df = pd.DataFrame(results)
# Out:
# collecting data for: AAPL
# collecting data for: MSFT
# collecting data for: NVDA
# collecting data for: AMD
# collecting data for: BUD
# collecting data for: V
# collecting data for: AMZN
# collecting data for: META
# collecting data for: WMT
# collecting data for: NSRGY
# collecting data for: UNA.AS
# collecting data for: DANOY
# collecting data for: OR.PA

# %%
# see all data collected
display(df)
# Out:
#                      address1           city state         zip  \
# 0          One Apple Park Way      Cupertino    CA       95014
# 1           One Microsoft Way        Redmond    WA  98052-6399
# 2   2788 San Tomas Expressway    Santa Clara    CA       95051
# 3        2485 Augustine Drive    Santa Clara    CA       95054
# 4            Brouwerijplein 1         Leuven   NaN        3000
# 5                 PO Box 8999  San Francisco    CA  94128-8999
# 6      410 Terry Avenue North        Seattle    WA  98109-5210
# 7                  1 Meta Way     Menlo Park    CA       94025
# 8   702 South West 8th Street    Bentonville    AR       72716
# 9            avenue NestlE 55          Vevey   NaN        1800
# 10             Unilever House         London   NaN    EC4Y 0DY
# 11    17, Boulevard Haussmann          Paris   NaN       75009
# 12             41, rue Martre         Clichy   NaN       92117
#
#            country             phone                        website  \
# ...

# %%
# specify what columns to keep
df_filtered = df[[
    'shortName'
    ,'industry'
    ,'currentPrice'
    ,'dividendRate'
    ,'dividendYield'
    ,'payoutRatio'
    ,'forwardPE'
    ,'fiveYearAvgDividendYield'
    ,'beta'
    ,'trailingPE'
    ,'marketCap'
    ,'currency'
    ,'profitMargins'
    ,'bookValue'
    ,'priceToBook'
    ,'earningsQuarterlyGrowth'
    ,'trailingEps'
    ,'forwardEps'
    ,'pegRatio'
    ,'trailingPegRatio'
    ,'enterpriseToRevenue'
    ,'enterpriseToEbitda'
    ,'quickRatio'
    ,'currentRatio'
    ,'revenuePerShare'
    ,'returnOnAssets'
    ,'returnOnEquity'
    ,'earningsGrowth'
    ,'revenueGrowth'
    ,'grossMargins'
    ,'ebitdaMargins'
    ,'operatingMargins'
    ,'recommendationMean'
    ,'recommendationKey'
    ]]

display(df_filtered)
# Out:
#                           shortName                        industry  \
# 0                        Apple Inc.            Consumer Electronics
# 1             Microsoft Corporation       Software - Infrastructure
# 2                NVIDIA Corporation                  Semiconductors
# 3      Advanced Micro Devices, Inc.                  Semiconductors
# 4   Anheuser-Busch Inbev SA Sponsor             Beverages - Brewers
# 5                         Visa Inc.                 Credit Services
# 6                  Amazon.com, Inc.                 Internet Retail
# 7              Meta Platforms, Inc.  Internet Content & Information
# 8                      Walmart Inc.                 Discount Stores
# 9   NESTLE SA SPON ADR EACH REPR 1                   Packaged Foods
# 10                     UNILEVER PLC   Household & Personal Products
# 11  DANONE ADR-EA CNV INTO 1/5 EUR0                  Packaged Foods
# 12                          L'OREAL   Household & Personal Products
#
# ...
